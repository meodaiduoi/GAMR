# %%
import sqlite3
import pandas as pd

def query_link_state(path):
    con = sqlite3.connect(path)
    cur = con.cursor()
    cur.execute('SELECT * FROM linkcost')
    
    rows = cur.fetchall()
    return rows
    con.close()
    
def query_link_last_state(path):
    con = sqlite3.connect(path)
    cur = con.cursor()
    cur.execute('SELECT * FROM linkcost WHERE time_id = (SELECT MAX(time_id) FROM linkcost)')
    
    rows = cur.fetchall()
    return rows
    con.close()


row = query_link_state('linkcost.db')

# %%
print(row)
# Out:
# [(2, 6, 7, 9999000.0, None, 0.0002983682983682828, None), (2, 6, 1, 9999000.0, None, 0.0002983682983682828, None), (2, 6, 2, 9999000.0, None, 0.0002983682983682828, None), (2, 6, 9, 4888.162136077881, None, 0.000298368298368328, None), (2, 6, 5, 11.246562004089355, 0.0, 0.00045820845820843434, None), (2, 6, 4, 9999000.0, None, 0.0002983682983682828, None), (2, 7, 6, 9999000.0, None, 0.0002983682983682828, None), (2, 7, 8, 9999000.0, None, 0.0002983682983682828, None), (2, 7, 4, 643.682599067688, None, 0.0001385281385281313, None), (2, 7, 2, 9999000.0, None, 0.0002983682983682828, None), (2, 7, 10, 9999000.0, None, 0.0001385281385281523, None), (2, 7, 5, 28.51271629333496, 0.0, 0.00045820845820843434, None), (2, 3, 8, 9999000.0, None, 0.0002983682983682828, None), (2, 3, 4, 9999000.0, None, 0.0001385281385281313, None), (2, 3, 2, 9999000.0, None, 0.000298368298368328, None), (2, 3, 9, 9999000.0, None, 0.0001385281385281313, None), (2, 3, 5, 25.278806686401367, 0.0, 0.0002983682983682828, None), (2, 8, 7, 9999000.0, None, 0.0002983682983682828, None), (2, 8, 3, 9999000.0, None, 0.0002983682983682828, None), (2, 8, 4, 9999000.0, None, 0.0001385281385281313, None), (2, 8, 1, 9999000.0, None, 0.0002983682983682828, None), (2, 8, 9, 9999000.0, None, 0.0001385281385281313, None), (2, 8, 10, 9999000.0, None, 0.000298368298368328, None), (2, 8, 5, 30.416250228881836, 0.0, 0.00045820845820843434, None), (2, 4, 6, 9999000.0, None, 0.0002983682983682828, None), (2, 4, 3, 9999000.0, None, 0.0001385281385281313, None), (2, 4, 8, 9999000.0, None, 0.0001385281385281313, None), (2, 4, 1, 9999000.0, None, 0.0001385281385281313, None), (2, 4, 2, 9999000.0, None, 0.000298368298368328, None), (2, 4, 9, 9999000.0, None, 0.0001385281385281313, None), (2, 4, 10, 9999000.0, None, 0.0002984676882078661, None), (2, 4, 5, 28.1832218170166, 0.0, 0.0001385281385281313, None), (2, 4, 7, 643.682599067688, None, 0.0001385281385281313, None), (2, 1, 6, 9999000.0, None, 0.0002983682983682828, None), (2, 1, 8, 9999000.0, None, 0.0002983682983682828, None), (2, 1, 2, 9999000.0, None, 0.0002983682983682828, None), (2, 1, 10, 9999000.0, None, 0.0002983682983682828, None), (2, 1, 4, 9999000.0, None, 0.0001385281385281313, None), (2, 1, 5, 40.1158332824707, 0.0, 0.0001385281385281313, None), (2, 2, 6, 9999000.0, None, 0.0002983682983682828, None), (2, 2, 7, 9999000.0, None, 0.0002983682983682828, None), (2, 2, 3, 9999000.0, None, 0.000298368298368328, None), (2, 2, 4, 9999000.0, None, 0.000298368298368328, None), (2, 2, 1, 9999000.0, None, 0.0002983682983682828, None), (2, 2, 10, 9999000.0, None, 0.0002983682983682828, None), (2, 2, 5, 40.331363677978516, 0.0, 0.00045820845820850373, None), (2, 9, 6, 4888.162136077881, None, 0.0001385281385281523, None), (2, 9, 3, 9999000.0, None, 0.0001385281385281313, None), (2, 9, 8, 9999000.0, None, 0.0001385281385281313, None), (2, 9, 10, 2606.478452682495, None, 0.000298368298368328, None), (2, 9, 5, 15.093088150024414, 0.0, 0.0002983682983682828, None), (2, 9, 4, 9999000.0, None, 0.0001385281385281313, None), (2, 10, 8, 9999000.0, None, 0.000298368298368328, None), (2, 10, 1, 9999000.0, None, 0.0002983682983682828, None), (2, 10, 2, 9999000.0, None, 0.0002983682983682828, None), (2, 10, 9, 2606.478452682495, None, 0.0002983682983682828, None), (2, 10, 5, 17.293334007263184, 0.0, 0.00045820845820843434, None), (2, 10, 7, 9999000.0, None, 0.0001385281385281523, None), (2, 10, 4, 9999000.0, None, 0.0002984676882078661, None), (2, 5, 6, 11.246562004089355, 0.0, 0.00045820845820843434, None), (2, 5, 8, 30.416250228881836, 0.0, 0.00045820845820843434, None), (2, 5, 4, 28.1832218170166, 0.0, 0.0001385281385281313, None), (2, 5, 1, 40.1158332824707, 0.0, 0.0001385281385281313, None), (2, 5, 2, 40.331363677978516, 0.0, 0.00045820845820850373, None), (2, 5, 9, 15.093088150024414, 0.0, 0.0002983682983682828, None), (2, 5, 10, 17.293334007263184, 0.0, 0.00045820845820843434, None), (2, 5, 3, 25.278806686401367, 0.0, 0.0002983682983682828, ...

# %%
import time
print("%.12f" % time.time())
print(time.time())
# Out:
# 1691438570.520884275436
# 1691438570.5209453

# %%
import pandas as pd

df = pd.DataFrame(row, columns=['timeid', 'src', 'dst', 'delay', 'packetloss', 'link_usage', 'free_bandwidth'])
df
# Out:
#        timeid  src  dst         delay  packetloss  link_usage free_bandwidth
# 0           0    6    7  9.999000e+06         NaN    0.000298           None
# 1           0    6    1  9.999000e+06         NaN    0.000298           None
# 2           0    6    2  9.999000e+06         NaN    0.000298           None
# 3           0    6    9  4.888699e+03         NaN    0.000139           None
# 4           0    6    5  1.185513e+01         0.0    0.000298           None
# ...       ...  ...  ...           ...         ...         ...            ...
# 12099     177    5    2  4.119325e+01         0.0    0.000457           None
# 12100     177    5    9  1.454186e+01         0.0    0.000457           None
# 12101     177    5   10  1.697898e+01         0.0    0.000298           None
# 12102     177    5    3  2.583742e+01         0.0    0.000298           None
# 12103     177    5    7  2.275288e+01         0.0    0.000298           None
#
# [12104 rows x 7 columns]
